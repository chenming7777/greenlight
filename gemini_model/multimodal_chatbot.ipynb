# %%
import google.generativeai as genai
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
from PIL import Image
import json
import base64
import io
import os
from dotenv import load_dotenv
import getpass



# Load environment variables
load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass(os.getenv("GOOGLE_API_KEY"))

# %%
# Initialize the Gemini Pro Vision model
model = genai.GenerativeModel('gemini-1.5-flash')

# Set up shared conversation memory
shared_memory = ConversationBufferMemory()

# Create a template for the model
template = """
You are a solar energy expert designed to assist farmers in the agrivoltaics industry, which combines agriculture with renewable energy generation. 
Your primary responsibilities include:
    Analyzing Graphs: You are proficient in interpreting various types of data visualizations related to solar energy production, weather patterns, and agricultural yield. You can provide detailed explanations and insights based on these graphs to help farmers optimize their operations.
    Monitoring Solar Panel Conditions: You have extensive knowledge about solar panel technology, maintenance, and performance. You can assess the condition of solar panels, identify potential issues, and suggest appropriate maintenance or troubleshooting steps to ensure optimal energy generation.
    Solving Farmer's Doubts: You are an expert in both agriculture and renewable energy. You can answer farmers' questions related to crop management under solar panels, the impact of solar shading on different types of crops, and strategies to maximize both agricultural yield and energy production. You offer practical advice and tailored solutions to help farmers achieve sustainable and efficient farming practices.
Your goal is to support farmers in integrating solar energy with agriculture, ensuring that they can benefit from increased energy production while maintaining or enhancing their agricultural output.
You should always provide detailed and informative responses to the farmers' questions, helping them understand the complex relationship between solar energy and agriculture.

User's input: {input}

Previous conversation:
{chat_history}

Your response:
"""

prompt = PromptTemplate(
    input_variables=["input", "chat_history"],
    template=template
)

def process_input(user_input, image_data=None):
    # Get the chat history
    chat_history = shared_memory.load_memory_variables({})['history']
    
    # Generate the full prompt using the template
    full_prompt = prompt.format(input=user_input if user_input else "Analyze the provided image", chat_history=chat_history)
    
    # Prepare the input for the model
    model_input = [full_prompt]
    
    # If image data is provided, add it to the input
    if image_data:
        try:
            image = Image.open(io.BytesIO(base64.b64decode(image_data)))
            model_input.append(image)
        except Exception as e:
            return {"error": f"Error processing image: {str(e)}"}
    
    # Generate content
    response = model.generate_content(model_input)
    
    # Update the shared memory
    shared_memory.save_context({"input": user_input if user_input else "Image analysis"}, {"output": response.text})
    
    return {"response": response.text}

def main(json_input):
    try:
        # Parse the JSON input
        data = json.loads(json_input)
        user_input = data.get("text_input")
        image_data = data.get("image")
        
        # Process the input
        result = process_input(user_input, image_data)
        
        # Return the result as JSON
        return json.dumps(result)
    except json.JSONDecodeError:
        return json.dumps({"error": "Invalid JSON input"})
    except Exception as e:
        return json.dumps({"error": str(e)})

# This model can aceept image, text and both image and text.
# It will accept the input in the form of JSON and return the response in the form of JSON.
# format is as follows:
# ({"text_input": "Analyze the efficiency graph.",
# "image": encoded_image}), jpg and png is fine
# Example usage
if __name__ == "__main__":
    # Text-only input
    text_only_input = json.dumps({
        "text_input": "What are the best practices for maintaining solar panels in an agricultural setting?"
    })
    print("Text-only response:", main(text_only_input))
    
    # Image-only input (assuming you have a base64 encoded image)
    with open("./test.png", "rb") as image_file:
        encoded_image = base64.b64encode(image_file.read()).decode('utf-8')
    image_only_input = json.dumps({
        "image": encoded_image
    })
    print("Image-only response:", main(image_only_input))
    
    # Text and image input
    with open("./image.png", "rb") as image_file:
        encoded_image = base64.b64encode(image_file.read()).decode('utf-8')
    text_and_image_input = json.dumps({
        "text_input": "Analyze the efficiency graph.",
        "image": encoded_image
    })
    print("Text and image response:", main(text_and_image_input))
# Out:
# Text-only response: {"response": "That's a great question! Maintaining solar panels in an agricultural setting is crucial for maximizing energy production and extending their lifespan. Here's a breakdown of best practices: \n\n**1. Regular Cleaning:**\n\n* **Frequency:** Aim for cleaning every 1-3 months, depending on the climate and dust accumulation. \n* **Methods:**\n    * **Soft-bristled brush:** For removing light dust and debris.\n    * **Water and mild soap:** For thorough cleaning. Avoid harsh chemicals or abrasive cleaners.\n    * **Pressure washer:** Use only on low pressure settings, as high pressure can damage the panels. \n* **Areas to focus on:**\n    * **Panel surfaces:** Remove dirt, bird droppings, and plant matter.\n    * **Framing and wiring:** Check for signs of corrosion or damage.\n\n**2. Vegetation Control:**\n\n* **Regular trimming:** Keep trees and shrubs pruned to avoid shading the panels.\n* **Weed control:** Use non-toxic methods like mulching or hand weeding to prevent weeds from growing near the panels.\n* **Avoid planting:** Keep a buffer zone around the panels free of crops or vegetation.\n\n**3. Monitoring and Inspections:**\n\n* **Visual inspections:** Regularly check for cracks, discoloration, or loose connections.\n* **Performance monitoring:** Use monitoring systems to track energy production and identify any drops in efficiency.\n* **Professional inspections:** Schedule regular inspections by qualified solar technicians.\n\n**4. Addressing Specific Issues:**\n\n* **Bird droppings:** Clean them promptly to avoid damage to the panels. \n* **Dust and soil:** Regular cleaning is essential. \n* **Snow and hail:**  Remove snow from the panels to prevent damage. \n* **Lightning strikes:**  Ensure panels are properly grounded to minimize damage.\n\n**5. Utilizing Technology:**\n\n* **Automated cleaning systems:** Consider robotic or solar-powered cleaning systems for efficient and consistent cleaning.\n* **Smart monitoring:** Utilize remote monitoring systems to track panel performance and receive alerts for potential issues.\n\nBy following these best practices, you can ensure your solar panels remain efficient and productive in your agricultural setting. Remember, proactive maintenance is key to maximizing your investment and ensuring a long lifespan for your solar system. \n\nIf you have any further questions or need specific advice for your situation, feel free to ask! \n"}
# Image-only response: {"response": "The graph you provided shows a comparison between the actual electricity generation of your solar panels and a predicted generation model. This is a useful tool to assess the performance of your system and identify areas for improvement. \n\nHere's what we can observe from the graph:\n\n* **The blue line represents the actual electricity generation:** This line shows the actual output of your solar panels over a period of time, likely measured in hours or days. \n* **The orange line represents the predicted electricity generation:** This line shows the expected output based on a predictive model. This model likely takes into account factors like weather conditions, panel efficiency, and time of day.\n* **The peaks and valleys:** The graph shows a cyclical pattern with peaks representing periods of high solar energy production and valleys representing periods of lower production. This is typical for solar panels, which generate the most electricity during daylight hours. \n* **The difference between the lines:** The graph highlights the differences between the actual generation and the predicted generation.  The larger the discrepancy between the two lines, the more significant the deviation from the expected performance.\n\n**Interpreting the differences:**\n\n* **Overestimation:** If the predicted generation (orange line) is consistently higher than the actual generation (blue line), it indicates that the model might be overestimating the output. This could be due to factors like:\n    * **Panel degradation:** The solar panels might be losing efficiency over time.\n    * **Soiling:** Dust, dirt, or bird droppings on the panels can reduce their efficiency.\n    * **Shading:**  Trees, crops, or other structures might be casting shadows on the panels, reducing the amount of sunlight they receive.\n    * **Weather conditions:**  The actual weather conditions might be different from the weather data used in the predictive model.\n* **Underestimation:** If the predicted generation (orange line) is consistently lower than the actual generation (blue line), it indicates that the model might be underestimating the output. This could be due to factors like:\n    * **Panel upgrades:**  Your solar panels might have been upgraded or replaced with more efficient ones.\n    * **Improved cleaning:** You might be cleaning your panels more regularly, increasing their efficiency.\n    * **Favorable weather:** The actual weather conditions might be more favorable than the weather data used in the predictive model.\n\n**Actionable Insights:**\n\n* **Identify the source of discrepancies:**  Analyze the graph to pinpoint the specific time periods where the differences are most pronounced.  This will help you understand the potential factors influencing the performance deviations.\n* **Investigate potential causes:** Based on your understanding of the specific time periods and the general trends, start investigating the potential reasons for the differences.  Consider factors like panel condition, cleaning practices, weather data accuracy, and any changes made to the solar system.\n* **Address any issues:** Once you identify the root cause of the performance discrepancies, take appropriate steps to address them. For example, you might need to:\n    * **Schedule panel cleaning:**  Regular cleaning can significantly improve panel efficiency.\n    * **Optimize panel positioning:**  Ensure the panels are positioned to maximize sunlight exposure and minimize shading.\n    * **Improve weather data accuracy:**  Use more reliable weather data for your predictive model.\n    * **Consider panel maintenance:**  Inspect your panels for any signs of damage or degradation.\n\nBy carefully analyzing this graph and taking appropriate actions, you can optimize your solar energy production and ensure that your agrivoltaic system is running at peak efficiency. If you have any further questions about interpreting this data or need spe ...
# Text and image response: {"response": "This graph shows a single line representing the actual electricity generation of your solar panels over time. It's a time series graph, showing the output of your solar system on November 27, 2019.\n\nLet's break down what we can see:\n\n* **The Y-axis:** It represents the electricity generation measured in units like kilowatt-hours (kWh) or megawatt-hours (MWh), depending on your solar system size. In this case, the Y-axis is likely in kWh, ranging from 0 to 400.\n* **The X-axis:** Represents time, but the specific time intervals are not shown. It could be hours, minutes, or even shorter intervals depending on your monitoring system's frequency.\n* **The shape of the line:** The line starts near zero, slowly increases, reaches a peak, then gradually decreases until it flattens out. This typical pattern reflects the natural behavior of solar energy production:\n    * **Morning:** The system begins generating electricity as the sun rises, so the line gradually increases.\n    * **Peak:** Around midday, the sun is highest, and the system produces its maximum electricity.\n    * **Afternoon and Evening:** As the sun sets, the electricity generation starts declining, explaining the descending part of the line.\n    * **Flattening:** Once the sun sets, the electricity generation drops to almost zero, and the line flattens.\n\n**Analyzing the Data:**\n\n* **Peak generation:** The highest point on the line indicates the maximum electricity your solar panels produced on that day. This value is around 400 kWh based on the graph's scale.\n* **Time of Peak:**  Identifying the precise time when the peak occurred would be helpful. It would indicate the time of day when your panels were most efficient.\n* **Overall Pattern:** The general shape of the line gives us an idea of how your system performed throughout the day.  It shows that the system experienced a period of high production followed by a gradual decline.\n\n**What this graph doesn't tell us:**\n\n* **Weather conditions:**  We need additional data like cloud cover, temperature, and sunlight intensity to analyze how these factors influenced the generation output.\n* **Comparisons:** This graph shows only the actual generation on a single day. To understand your system's overall performance, you'd need to compare it with other days, different seasons, and perhaps even a predicted generation model.\n\n**Recommendations:**\n\n* **Data collection:** You can collect more data to get a better understanding of your solar system's performance. Record weather conditions alongside the electricity generation for a thorough analysis.\n* **Predictive modeling:** If you haven't already, consider using a predictive model for your solar system. This would allow you to compare the predicted output with your actual generation and identify any discrepancies.\n* **Performance optimization:**  Once you have more data, you can use this information to identify areas where you can improve your system's performance.  This might involve adjusting panel positioning, cleaning practices, or even addressing any shading issues.\n\nRemember, understanding your solar system's performance is crucial for maximizing energy production and making informed decisions about your agrivoltaic operation. If you have any further questions or need more specific guidance, feel free to ask!\n"}
